# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Using forward slashes (recommended)
df = pd.read_csv('../dataset/data.csv')

# %%
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0             49188              4                  2                       0
# 1             49188              1                  2                       0
# 2             49188              1                  2                       0
# 3             49188              1                  2                       0
# 4             49486              3                  2                       0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                           12                            0
# 1                           12                            0
# 2                           12                            0
# 3                           12                            0
# 4                           12                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...

# %%
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist()[:20], "...")
print("\nData Types:\n", df.dtypes.value_counts())
print("\nFirst 5 rows:\n", df.head())
print("\nMissing Values:\n", df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Shape: (50000, 79)
#
# Columns: ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min'] ...
#
# Data Types:
#  int64      54
# float64    24
# object      1
# Name: count, dtype: int64
#
# First 5 rows:
#     Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0             49188              4                  2                       0
# 1             49188              1                  2                       0
# 2             49188              1                  2                       0
# ...

# %%
df.describe()
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      50000.000000   5.000000e+04       50000.000000
# mean        6442.265900   2.126530e+07          50.427880
# std        16714.198216   3.793673e+07        2851.204804
# min            0.000000  -1.000000e+00           1.000000
# 25%           53.000000   2.354975e+04           2.000000
# 50%          443.000000   2.619930e+05           3.000000
# 75%          443.000000   1.494485e+07           8.000000
# max        65454.000000   1.199999e+08      219759.000000
#
# ...

# %%
plt.figure(figsize=(12,8))
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr().iloc[:20, :20], cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap (Top 20 Features)")
plt.show()

# --- Feature Distributions ---
num_cols = df.select_dtypes(include='number').columns[:5]
df[num_cols].hist(bins=30, figsize=(12,8))
plt.suptitle("Feature Distributions")
plt.show()

# %%
plt.figure(figsize=(12,6))
df['Label'].value_counts().plot(kind='bar', color="teal")
plt.title("Attack Distribution")
plt.xlabel("Attack Type")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
attack_dist = df['Label'].value_counts(normalize=True) * 100
print("\nClass Distribution (%):\n", attack_dist)
# Out:
# Class Distribution (%):
#  Label
# BENIGN    100.0
# Name: proportion, dtype: float64

# %%
if 'Label' in df.select_dtypes(include=np.number).columns:
    cor_target = corr['Label'].sort_values(ascending=False)
    print("\nTop 10 Correlated Features with Label:\n", cor_target.head(10))

# %%
num_cols = df.select_dtypes(include=np.number).columns[:8]  # first 8 numeric features
df[num_cols].hist(bins=30, figsize=(16,10), edgecolor="black")
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
skew_vals = df[num_cols].skew()
kurt_vals = df[num_cols].kurt()

print("\nSkewness:\n", skew_vals)
print("\nKurtosis:\n", kurt_vals)
# Out:
# Skewness:
#  Destination Port                2.391044
# Flow Duration                   1.639610
# Total Fwd Packets              71.688654
# Total Backward Packets         71.960514
# Total Length of Fwd Packets    58.786451
# Total Length of Bwd Packets    71.706669
# Fwd Packet Length Max          13.523913
# Fwd Packet Length Min          14.329312
# dtype: float64
#
# Kurtosis:
#  Destination Port                  3.893866
# Flow Duration                     1.139641
# Total Fwd Packets              5187.034180
# Total Backward Packets         5236.924245
# Total Length of Fwd Packets    3815.112996
# Total Length of Bwd Packets    5184.003360
# Fwd Packet Length Max           402.653790
# Fwd Packet Length Min           628.654370
# dtype: float64
